# %%
import pandas as pd

# %%
df1 = pd.read_csv('..\Resources\jc-201901-citibike-tripdata.csv')
df1.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
df2= pd.read_csv('..\Resources\jc-201902-citibike-tripdata.csv')
df2.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...

# %%
df3 = pd.read_csv('..\Resources\jc-201903-citibike-tripdata.csv')
df3.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           306   47:08.2  52:14.7              3183     Exchange Place
# 1           123   30:53.0  32:56.8              3183     Exchange Place
# 2           328   18:30.4  23:59.1              3183     Exchange Place
# 3            95   04:47.2  06:22.8              3183     Exchange Place
# 4           169   51:29.4  54:19.2              3183     Exchange Place
#
#    start station latitude  start station longitude  end station id  \
# 0               40.716247               -74.033459            3267
# 1               40.716247               -74.033459            3184
# 2               40.716247               -74.033459            3213
# 3               40.716247               -74.033459            3184
# 4               40.716247               -74.033459            3639
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
citibike_Q12019 = pd.concat([df1, df2, df3])
citibike_Q12019
# Out:
#        tripduration starttime stoptime  start station id start station name  \
# 0               306   47:08.2  52:14.7              3183     Exchange Place
# 1               123   30:53.0  32:56.8              3183     Exchange Place
# 2               328   18:30.4  23:59.1              3183     Exchange Place
# 3                95   04:47.2  06:22.8              3183     Exchange Place
# 4               169   51:29.4  54:19.2              3183     Exchange Place
# 5               257   08:37.8  12:55.3              3183     Exchange Place
# 6               440   13:46.3  21:06.3              3183     Exchange Place
# 7               193   40:34.6  43:47.7              3183     Exchange Place
# 8               278   37:44.3  42:23.2              3183     Exchange Place
# 9               277   37:47.0  42:24.6              3183     Exchange Place
# 10             1170   23:38.8  43:08.8              3183     Exchange Place
# ...

# %%
citibike_Q12019.to_csv('citibike_Q12019.csv', sep = ',')
